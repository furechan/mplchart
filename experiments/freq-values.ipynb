# %%
FREQ_VALUES = {
    '1m': 1 / 1400,
    '2m': 2 / 1440,
    '5m': 5 / 1440,
    '10m': 10 / 1440,
    '20m': 20 / 1440,
    '30m': 30 / 1440,
    '1h': 1 / 24,
    '2h': 2 / 24,
    '1D': 1,
    '1W': 7,
    '2W': 14,
    '1S': 30,
    '3M': 90,
    '1Y': 360,
    '2Y': 720,
    '5Y': 1800,
    '10Y': 3600
}

# %%
for freq, value in reversed(FREQ_VALUES.items()):
    print(f"{freq}: {value}")
# Out:
# 10Y: 3600
# 5Y: 1800
# 2Y: 720
# 1Y: 360
# 3M: 90
# 1S: 30
# 2W: 14
# 1W: 7
# 1D: 1
# 2h: 0.08333333333333333
# 1h: 0.041666666666666664
# 30m: 0.020833333333333332
# 20m: 0.013888888888888888
# 10m: 0.006944444444444444
# 5m: 0.003472222222222222
# 2m: 0.001388888888888889
# 1m: 0.0007142857142857143

# %%
import re
re.match(r'(\d+)([a-zA-Z]+)', '5m').groups()
# Out:
# ('5', 'm')
