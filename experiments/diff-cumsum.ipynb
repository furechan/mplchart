# %%
import numpy as np

a = np.array([1, 1, 5, 5, 8, 8])

idx = np.cumsum(np.r_[0, a[1:] != a[:-1]])

print(idx)
# Out:
# [0 0 1 1 2 2]

# %%
np.diff(a)
# Out:
# array([0, 4, 0, 3, 0])

# %%
np.diff(a, prepend=a[0])
# Out:
# array([0, 0, 4, 0, 3, 0])
