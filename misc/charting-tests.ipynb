# %% [markdown]
# # Charting Tests

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import *
from mplchart.indicators import *

# %%
ticker = "AAPL"
prices = yf.Ticker(ticker).history(period="5y")
prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-03-29 00:00:00-04:00   45.687276   45.747445   45.376804   45.716156
# 2019-04-01 00:00:00-04:00   46.122906   46.132532   45.338308   46.026638
# 2019-04-02 00:00:00-04:00   45.990534   46.801611   45.980909   46.695713
# 2019-04-03 00:00:00-04:00   46.510390   47.292583   46.486321   47.015808
# 2019-04-04 00:00:00-04:00   46.881032   47.261298   46.483920   47.097641
# ...                               ...         ...         ...         ...
# 2024-03-22 00:00:00-04:00  171.759995  173.050003  170.059998  172.279999
# 2024-03-25 00:00:00-04:00  170.570007  171.940002  169.449997  170.850006
# 2024-03-26 00:00:00-04:00  170.000000  171.419998  169.580002  169.710007
# 2024-03-27 00:00:00-04:00  170.410004  173.600006  170.110001  173.309998
# 2024-03-28 00:00:00-04:00  171.750000  172.229996  170.509995  171.479996
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-03-29 00:00:00-04:00   94256000        0.0           0.0
# 2019-04-01 00:00:00-04:00  111448000        0.0           0.0
# 2019-04-02 00:00:00-04:00   91062800        0.0           0.0
# 2019-04-03 00:00:00-04:00   93087200        0.0           0.0
# 2019-04-04 00:00:00-04:00   76457200        0.0           0.0
# ...                              ...        ...           ...
# 2024-03-22 00:00:00-04:00   71106600        0.0           0.0
# 2024-03-25 00:00:00-04:00   54288300        0.0           0.0
# 2024-03-26 00:00:00-04:00   57388400        0.0           0.0
# 2024-03-27 00:00:00-04:00   60273300        0.0           0.0
# 2024-03-28 00:00:00-04:00   65672700        0.0           0.0
#
# [1259 rows x 7 columns]

# %%
max_bars = 250

indicators = [
    Candlesticks(),
    Volume(),
    SMA(50),
    SMA(200),
    BBANDS(),
    RSI(),
    ADX(),
    MACD(),
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
chart.show()
