# %% [markdown]
# # AreaPlot Primitive

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import Candlesticks, Price, Volume, AreaPlot
from mplchart.indicators import SMA, EMA, RSI, ROC, ATRP, MACD, DMI

# %%
ticker = "AAPL"
prices = yf.Ticker(ticker).history(period="5y")
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1255 entries, 2021-03-04 00:00:00-05:00 to 2026-03-03 00:00:00-05:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          1255 non-null   float64
#  1   High          1255 non-null   float64
#  2   Low           1255 non-null   float64
#  3   Close         1255 non-null   float64
#  4   Volume        1255 non-null   int64
#  5   Dividends     1255 non-null   float64
#  6   Stock Splits  1255 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 78.4 KB

# %%
Chart(prices, title=ticker, max_bars=250).plot(
    Candlesticks(),
).plot(
    ROC(20) | AreaPlot(color="red", alpha=0.5), target="below"
).show()
