# %% [markdown]
# # Mplchart Tests

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import Candlesticks, Volume, Peaks, Price
from mplchart.indicators import SMA, EMA, WMA, HMA, ROC, RSI, MACD, DMI, STOCH, TSF, ALMA, BBANDS, KELTNER, CCI

# %%
ticker = "AAPL"
prices = yf.Ticker(ticker).history(period="5y")
prices = prices.rename(columns=str.lower).rename_axis(index=str.lower)
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2021-03-01 00:00:00-05:00 to 2026-02-27 00:00:00-05:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   open          1256 non-null   float64
#  1   high          1256 non-null   float64
#  2   low           1256 non-null   float64
#  3   close         1256 non-null   float64
#  4   volume        1256 non-null   int64
#  5   dividends     1256 non-null   float64
#  6   stock splits  1256 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 78.5 KB

# %%
prices.rename(columns=str.lower)[["high", "low", "close"]].mean(axis=1)
# Out:
# date
# 2021-03-01 00:00:00-05:00    122.889023
# 2021-03-02 00:00:00-05:00    122.999398
# 2021-03-03 00:00:00-05:00    119.999504
# 2021-03-04 00:00:00-05:00    117.642457
# 2021-03-05 00:00:00-05:00    117.181387
#                                 ...
# 2026-02-23 00:00:00-05:00    266.329997
# 2026-02-24 00:00:00-05:00    271.580007
# 2026-02-25 00:00:00-05:00    273.406667
# 2026-02-26 00:00:00-05:00    273.286662
# 2026-02-27 00:00:00-05:00    266.626668
# Length: 1256, dtype: float64

# %%
Chart(prices, title=ticker, max_bars=100).plot(
    Candlesticks(),
    ALMA(),
).plot(
    ROC(1) @ ALMA(),
    Peaks(1),
    target="below"
).show()
