# %% [markdown]
# # Talib Functions (playground)

# %%
import pandas as pd
import yfinance as yf

from talib import get_functions
from talib import abstract
from talib.abstract import Function

from mplchart.chart import Chart
from mplchart.samples import sample_prices
from mplchart.primitives import Candlesticks

from IPython.display import display

# %%
prices = sample_prices()
prices
# Out:
#                   open        high         low       close     volume
# date
# 1980-12-12    0.099058    0.099488    0.099058    0.099058  469033600
# 1980-12-15    0.094321    0.094321    0.093890    0.093890  175884800
# 1980-12-16    0.087429    0.087429    0.086999    0.086999  105728000
# 1980-12-17    0.089152    0.089582    0.089152    0.089152   86441600
# 1980-12-18    0.091736    0.092167    0.091736    0.091736   73449600
# ...                ...         ...         ...         ...        ...
# 2024-05-29  189.610001  192.250000  189.509995  190.289993   53068000
# 2024-05-30  190.759995  192.179993  190.630005  191.289993   49947900
# 2024-05-31  191.440002  192.570007  189.910004  192.250000   75158300
# 2024-06-03  192.899994  194.990005  192.520004  194.029999   50031100
# 2024-06-04  194.720001  195.320007  193.034195  194.529999   29703490
#
# [10960 rows x 5 columns]

# %%
functions = [Function(name).info for name in get_functions()]
functions = pd.DataFrame(functions).set_index("name")
functions
# Out:
#                               group  \
# name
# HT_DCPERIOD        Cycle Indicators
# HT_DCPHASE         Cycle Indicators
# HT_PHASOR          Cycle Indicators
# HT_SINE            Cycle Indicators
# HT_TRENDMODE       Cycle Indicators
# ...                             ...
# NATR          Volatility Indicators
# TRANGE        Volatility Indicators
# AD                Volume Indicators
# ADOSC             Volume Indicators
# OBV               Volume Indicators
#
#                                            display_name  \
# name
# HT_DCPERIOD   Hilbert Transform - Dominant Cycle Period
# HT_DCPHASE     Hilbert Transform - Dominant Cycle Phase
# HT_PHASOR         Hilbert Transform - Phasor Components
# HT_SINE                    Hilbert Transform - SineWave
# HT_TRENDMODE    Hilbert Transform - Trend vs Cycle Mode
# ...                                                 ...
# NATR                      Normalized Average True Range
# TRANGE                                       True Range
# AD                                     Chaikin A/D Line
# ADOSC                            Chaikin A/D Oscillator
# OBV                                   On Balance Volume
#
#                                  function_flags  \
# name
# HT_DCPERIOD   [Function has an unstable period]
# HT_DCPHASE    [Function has an unstable period]
# HT_PHASOR     [Function has an unstable period]
# HT_SINE       [Function has an unstable period]
# HT_TRENDMODE  [Function has an unstable period]
# ...                                         ...
# NATR          [Function has an unstable period]
# TRANGE                                     None
# AD                                         None
# ADOSC                                      None
# OBV                                        None
#
#                                                  input_names  \
# name
# HT_DCPERIOD                               {'price': 'close'}
# HT_DCPHASE                                {'price': 'close'}
# HT_PHASOR                                 {'price': 'close'}
# HT_SINE                                   {'price': 'close'}
# HT_TRENDMODE                              {'price': 'close'}
# ...                                                      ...
# NATR                    {'prices': ['high', 'low', 'close']}
# TRANGE                  {'prices': ['high', 'low', 'close']}
# AD            {'prices': ['high', 'low', 'close', 'volume']}
# ADOSC         {'prices': ['high', 'low', 'close', 'volume']}
# OBV                 {'price': 'close', 'prices': ['volume']}
#
#                                        parameters  \
# name
# HT_DCPERIOD                                    {}
# HT_DCPHASE                                     {}
# HT_PHASOR                                      {}
# HT_SINE                                        {}
# HT_TRENDMODE                                   {}
# ...                                           ...
# NATR                           {'timeperiod': 14}
# TRANGE                                         {}
# AD                                             {}
# ADOSC         {'fastperiod': 3, 'slowperiod': 10}
# OBV                                            {}
#
#                                                    output_flags  \
# name
# HT_DCPERIOD                                  {'real': ['Line']}
# HT_DCPHASE                                   {'real': ['Line']}
# HT_PHASOR     {'inphase': ['Line'], 'quadrature': ['Dashed L...
# HT_SINE         {'sine': ['Line'], 'leadsine': ['Dashed Line']}
# HT_TRENDMODE                              {'integer': ['Line']}
# ...                                                         ...
# NATR                                         {'real': ['Line']}
# TRANGE                                       {'real': ['Line']}
# AD                                           {'real': ['Line']}
# ADOSC                                        {'real': ['Line']}
# OBV                                          {'real': ['Line']}
#
#                        output_names
# name
# HT_DCPERIOD                  [real]
# HT_DCPHASE                   [real]
# HT_PHASOR     [inphase, quadrature]
# HT_SINE            [sine, leadsine]
# HT_TRENDMODE              [integer]
# ...                             ...
# NATR                         [real]
# TRANGE                       [real]
# AD                           [real]
# ADOSC                        [real]
# OBV                          [real]
#
# [158 rows x 7 columns]

# %%
flags = [
    (name, item, ":".join(flags))
    for name in get_functions()
    for item, flags in Function(name).output_flags.items()
]

flags = pd.DataFrame.from_records(flags, columns=["name", "item", "flag"]).set_index(["name", "item"])

flags.style

# %%
flags.query("flag != 'Line'")
# Out:
#                                                  flag
# name      item
# HT_PHASOR quadrature                      Dashed Line
# HT_SINE   leadsine                        Dashed Line
# AROON     aroondown                       Dashed Line
# MACD      macdsignal                      Dashed Line
#           macdhist                          Histogram
# MACDEXT   macdsignal                      Dashed Line
#           macdhist                          Histogram
# MACDFIX   macdsignal                      Dashed Line
#           macdhist                          Histogram
# STOCH     slowk                           Dashed Line
#           slowd                           Dashed Line
# BBANDS    upperband   Values represent an upper limit
#           lowerband    Values represent a lower limit
# MAMA      fama                            Dashed Line

# %%
flags.query("item not in ('real', 'integer')")
# Out:
#                                                    flag
# name        item
# HT_PHASOR   inphase                                Line
#             quadrature                      Dashed Line
# HT_SINE     sine                                   Line
#             leadsine                        Dashed Line
# MINMAX      min                                    Line
#             max                                    Line
# MINMAXINDEX minidx                                 Line
#             maxidx                                 Line
# AROON       aroondown                       Dashed Line
#             aroonup                                Line
# MACD        macd                                   Line
#             macdsignal                      Dashed Line
#             macdhist                          Histogram
# MACDEXT     macd                                   Line
#             macdsignal                      Dashed Line
#             macdhist                          Histogram
# MACDFIX     macd                                   Line
#             macdsignal                      Dashed Line
#             macdhist                          Histogram
# STOCH       slowk                           Dashed Line
#             slowd                           Dashed Line
# STOCHF      fastk                                  Line
#             fastd                                  Line
# STOCHRSI    fastk                                  Line
#             fastd                                  Line
# BBANDS      upperband   Values represent an upper limit
#             middleband                             Line
#             lowerband    Values represent a lower limit
# MAMA        mama                                   Line
#             fama                            Dashed Line

# %%
fn = Function("SMA", 50)

def test_function(fn):
    display(fn)
    display(vars(fn))

test_function(fn)
# Out:
# {'name': 'SMA', 'group': 'Overlap Studies', 'display_name': 'Simple Moving Average', 'function_flags': ['Output scale same as input'], 'input_names': OrderedDict([('price', 'close')]), 'parameters': OrderedDict([('timeperiod', 50)]), 'output_flags': OrderedDict([('real', ['Line'])]), 'output_names': ['real']}
# {'_Function__name': b'SMA',
#  '_Function__namestr': 'SMA',
#  '_Function__localdata': <_thread._local at 0x122151040>,
#  'func_object': <function talib._ta_lib.SMA(real, timeperiod=-2147483648)>}

# %%
fn.info
# Out:
# {'name': 'SMA',
#  'group': 'Overlap Studies',
#  'display_name': 'Simple Moving Average',
#  'function_flags': ['Output scale same as input'],
#  'input_names': OrderedDict([('price', 'close')]),
#  'parameters': OrderedDict([('timeperiod', 50)]),
#  'output_flags': OrderedDict([('real', ['Line'])]),
#  'output_names': ['real']}

# %%
fn(prices)
# Out:
# date
# 1980-12-12           NaN
# 1980-12-15           NaN
# 1980-12-16           NaN
# 1980-12-17           NaN
# 1980-12-18           NaN
#                  ...
# 2024-05-29    176.423375
# 2024-05-30    176.732345
# 2024-05-31    177.008785
# 2024-06-03    177.466627
# 2024-06-04    177.916294
# Length: 10960, dtype: float64

# %%
help(abstract.Function("SMA"))

# %%
res = abstract.Function("MACD")(prices)
print(type(res).__name__)
res
# Out:
# DataFrame
#                 macd  macdsignal  macdhist
# date
# 1980-12-12       NaN         NaN       NaN
# 1980-12-15       NaN         NaN       NaN
# 1980-12-16       NaN         NaN       NaN
# 1980-12-17       NaN         NaN       NaN
# 1980-12-18       NaN         NaN       NaN
# ...              ...         ...       ...
# 2024-05-29  4.371958    4.428581 -0.056623
# 2024-05-30  4.290437    4.400952 -0.110515
# 2024-05-31  4.254256    4.371613 -0.117357
# 2024-06-03  4.319421    4.361174 -0.041753
# 2024-06-04  4.361138    4.361167 -0.000029
#
# [10960 rows x 3 columns]

# %%
fn
# Out:
# {'name': 'SMA', 'group': 'Overlap Studies', 'display_name': 'Simple Moving Average', 'function_flags': ['Output scale same as input'], 'input_names': OrderedDict([('price', 'close')]), 'parameters': OrderedDict([('timeperiod', 50)]), 'output_flags': OrderedDict([('real', ['Line'])]), 'output_names': ['real']}

# %%
fn.info
# Out:
# {'name': 'SMA',
#  'group': 'Overlap Studies',
#  'display_name': 'Simple Moving Average',
#  'function_flags': ['Output scale same as input'],
#  'input_names': OrderedDict([('price', 'close')]),
#  'parameters': OrderedDict([('timeperiod', 50)]),
#  'output_flags': OrderedDict([('real', ['Line'])]),
#  'output_names': ['real']}

# %%
vars(fn)
# Out:
# {'_Function__name': b'SMA',
#  '_Function__namestr': 'SMA',
#  '_Function__localdata': <_thread._local at 0x122151040>,
#  'func_object': <function talib._ta_lib.SMA(real, timeperiod=-2147483648)>}

# %%
vars(fn.func_object)
# Out:
# {'__wrapped__': <cyfunction SMA at 0x115b5ee80>}

# %%
str(fn)
# Out:
# 'SMA([input_arrays], [timeperiod=50])\n\nSimple Moving Average (Overlap Studies)\n\nInputs:\n    price: (any ndarray)\nParameters:\n    timeperiod: 50\nOutputs:\n    real'

# %%
repr(fn)
# Out:
# "{'name': 'SMA', 'group': 'Overlap Studies', 'display_name': 'Simple Moving Average', 'function_flags': ['Output scale same as input'], 'input_names': OrderedDict([('price', 'close')]), 'parameters': OrderedDict([('timeperiod', 50)]), 'output_flags': OrderedDict([('real', ['Line'])]), 'output_names': ['real']}"

# %%
dir(fn)
# Out:
# ['_Function__call_function',
#  '_Function__check_opt_input_value',
#  '_Function__get_opt_input_value',
#  '_Function__input_price_series_names',
#  '_Function__local',
#  '_Function__localdata',
#  '_Function__name',
#  '_Function__namestr',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  'func_object',
#  'function_flags',
#  'get_input_arrays',
#  'get_input_names',
#  'get_parameters',
#  'info',
#  'input_arrays',
#  'input_names',
#  'lookback',
#  'output_flags',
#  'output_names',
#  'outputs',
#  'parameters',
#  'run',
#  'set_function_args',
#  'set_input_arrays',
#  'set_input_names',
#  'set_parameters']

# %%
SMA20 = abstract.Function("SMA", timeperiod=20)

# %%
SMA20(prices)
# Out:
# date
# 1980-12-12           NaN
# 1980-12-15           NaN
# 1980-12-16           NaN
# 1980-12-17           NaN
# 1980-12-18           NaN
#                  ...
# 2024-05-29    185.652359
# 2024-05-30    186.763325
# 2024-05-31    187.736044
# 2024-06-03    188.280963
# 2024-06-04    188.934269
# Length: 10960, dtype: float64
