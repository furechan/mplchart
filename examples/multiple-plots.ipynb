# %% [markdown]
# # Multiple Asset Plots (tentative)

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import Candlesticks, Volume, Price
from mplchart.indicators import SMA, RSI, MACD

# %% [markdown]
# ## Fetching the prices

# %%
ticker = "AAPL"
aapl = yf.Ticker(ticker).history(period="5y")
aapl
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-03-15 00:00:00-04:00   44.488722   45.085594   44.221573   44.794376
# 2019-03-18 00:00:00-04:00   44.717361   45.340708   44.714952   45.251659
# 2019-03-19 00:00:00-04:00   45.331089   45.485120   44.746247   44.893059
# 2019-03-20 00:00:00-04:00   44.820858   45.605460   44.459846   45.285362
# 2019-03-21 00:00:00-04:00   45.733009   47.251666   45.682466   46.953228
# ...                               ...         ...         ...         ...
# 2024-03-11 00:00:00-04:00  172.940002  174.380005  172.050003  172.750000
# 2024-03-12 00:00:00-04:00  173.149994  174.029999  171.009995  173.229996
# 2024-03-13 00:00:00-04:00  172.770004  173.190002  170.759995  171.130005
# 2024-03-14 00:00:00-04:00  172.910004  174.309998  172.050003  173.000000
# 2024-03-15 00:00:00-04:00  171.000000  172.470001  170.289993  171.509995
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-03-15 00:00:00-04:00  156171600        0.0           0.0
# 2019-03-18 00:00:00-04:00  104879200        0.0           0.0
# 2019-03-19 00:00:00-04:00  126585600        0.0           0.0
# 2019-03-20 00:00:00-04:00  124140800        0.0           0.0
# 2019-03-21 00:00:00-04:00  204136800        0.0           0.0
# ...                              ...        ...           ...
# 2024-03-11 00:00:00-04:00   60139500        0.0           0.0
# 2024-03-12 00:00:00-04:00   59825400        0.0           0.0
# 2024-03-13 00:00:00-04:00   52488700        0.0           0.0
# 2024-03-14 00:00:00-04:00   72913500        0.0           0.0
# 2024-03-15 00:00:00-04:00   65623809        0.0           0.0
#
# [1260 rows x 7 columns]

# %%
ticker = "MSFT"
msft = yf.Ticker(ticker).history(period="5y")
msft
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-03-15 00:00:00-04:00  109.791254  111.609372  109.077335  110.333839
# 2019-03-18 00:00:00-04:00  110.581328  111.952055  110.467105  111.913979
# 2019-03-19 00:00:00-04:00  112.408971  112.742139  111.361890  111.990143
# 2019-03-20 00:00:00-04:00  111.742658  113.037233  111.095371  111.866402
# 2019-03-21 00:00:00-04:00  111.504670  115.007635  111.457073  114.436501
# ...                               ...         ...         ...         ...
# 2024-03-11 00:00:00-04:00  403.760010  405.679993  401.260010  404.519989
# 2024-03-12 00:00:00-04:00  407.619995  415.570007  406.790009  415.279999
# 2024-03-13 00:00:00-04:00  418.100006  418.179993  411.450012  415.100006
# 2024-03-14 00:00:00-04:00  420.239990  427.820007  417.989990  425.220001
# 2024-03-15 00:00:00-04:00  419.274994  422.600006  412.790009  416.559998
#
#                              Volume  Dividends  Stock Splits
# Date
# 2019-03-15 00:00:00-04:00  54681100        0.0           0.0
# 2019-03-18 00:00:00-04:00  31207600        0.0           0.0
# 2019-03-19 00:00:00-04:00  37588700        0.0           0.0
# 2019-03-20 00:00:00-04:00  28113300        0.0           0.0
# 2019-03-21 00:00:00-04:00  29854400        0.0           0.0
# ...                             ...        ...           ...
# 2024-03-11 00:00:00-04:00  16120800        0.0           0.0
# 2024-03-12 00:00:00-04:00  22457000        0.0           0.0
# 2024-03-13 00:00:00-04:00  17115900        0.0           0.0
# 2024-03-14 00:00:00-04:00  34157300        0.0           0.0
# 2024-03-15 00:00:00-04:00  29029261        0.0           0.0
#
# [1260 rows x 7 columns]

# %% [markdown]
# ## Creating the Chart

# %%
# Multiple plots without rebase

title = "AAPL vs MSFT"
max_bars = 250

indicators = [
    Candlesticks(),
    Volume(),
    RSI(),
    MACD(),
]

chart = Chart(title=title, max_bars=max_bars)
chart.plot(aapl, indicators)
chart.plot(msft, [Price()], target="main")

# %%
# Multiple plots with rebase

chart = Chart(title=title, max_bars=max_bars)
chart.plot(aapl, indicators)
chart.plot(msft, [Price()], target="main", rebase=True)
