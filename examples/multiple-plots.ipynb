# %% [markdown]
# # Multiple Asset Plots (tentative)

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import OHLC, Candlesticks, Volume, Price
from mplchart.indicators import SMA, RSI, MACD

# %% [markdown]
# ## Fetching the prices

# %%
ticker = 'AAPL'
aapl = yf.Ticker(ticker).history(period='5y')
aapl
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2018-12-17 00:00:00-05:00   39.700184   40.396049   39.047512   39.337856
# 2018-12-18 00:00:00-05:00   39.683385   40.199282   39.445831   39.848953
# 2018-12-19 00:00:00-05:00   39.832150   40.180081   38.174076   38.605991
# 2018-12-20 00:00:00-05:00   38.488416   38.898736   37.264659   37.631786
# 2018-12-21 00:00:00-05:00   37.638987   37.950926   35.904130   36.168076
# ...                               ...         ...         ...         ...
# 2023-12-11 00:00:00-05:00  193.110001  193.490005  191.419998  193.179993
# 2023-12-12 00:00:00-05:00  193.080002  194.720001  191.720001  194.710007
# 2023-12-13 00:00:00-05:00  195.089996  198.000000  194.850006  197.960007
# 2023-12-14 00:00:00-05:00  198.020004  199.619995  196.160004  198.110001
# 2023-12-15 00:00:00-05:00  197.529999  198.399994  197.000000  197.570007
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
ticker = 'NVDA'
nvda = yf.Ticker(ticker).history(period='5y')
nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2018-12-17 00:00:00-05:00   36.027958   36.749804   35.035725   35.616180
# 2018-12-18 00:00:00-05:00   36.055250   37.290578   35.782384   36.449661
# 2018-12-19 00:00:00-05:00   36.112297   36.648103   33.842563   34.358524
# 2018-12-20 00:00:00-05:00   34.274190   35.174642   32.914832   33.512653
# 2018-12-21 00:00:00-05:00   33.778077   34.107995   31.865551   32.140896
# ...                               ...         ...         ...         ...
# 2023-12-11 00:00:00-05:00  474.910004  475.309998  458.299988  466.269989
# 2023-12-12 00:00:00-05:00  460.459991  476.660004  460.459991  476.570007
# 2023-12-13 00:00:00-05:00  476.290009  485.940002  476.079987  480.880005
# 2023-12-14 00:00:00-05:00  483.899994  486.700012  474.220001  483.500000
# 2023-12-15 00:00:00-05:00  481.940002  494.040009  481.200012  488.899994
#
#                              Volume  Dividends  Stock Splits
# Date
# ...

# %% [markdown]
# ## Creating the Chart

# %%
# Multiple plots without rebase

style = 'tableau'
max_bars = 250
title = "AAPL vs NVDA"

indicators = [
    Candlesticks(), Volume(),
    RSI(),
    MACD(),
]

chart = Chart(title=title, max_bars=max_bars, style=style)
chart.plot(aapl, indicators)
chart.plot(nvda, [ Price() ] , target='main')

# %%
# Multiple plots with rebase

chart = Chart(title=title, max_bars=max_bars, style=style)
chart.plot(aapl, indicators)
chart.plot(nvda, [ Price() ] , target='main', rebase=True)
