# %% [markdown]
# # Multiple Asset Plots (tentative)

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import Candlesticks, Volume, Price
from mplchart.indicators import SMA, RSI, MACD

# %% [markdown]
# ## Fetching the prices

# %%
ticker = "AAPL"
aapl = yf.Ticker(ticker).history(period="5y")
aapl
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-02-25 00:00:00-05:00   41.915909   42.327461   41.865366   41.932755
# 2019-02-26 00:00:00-05:00   41.807608   42.190280   41.677642   41.956825
# 2019-02-27 00:00:00-05:00   41.687271   42.118077   41.571744   42.086788
# 2019-02-28 00:00:00-05:00   41.954418   42.096415   41.617471   41.672825
# 2019-03-01 00:00:00-05:00   41.944793   42.154179   41.610255   42.110859
# ...                               ...         ...         ...         ...
# 2024-02-16 00:00:00-05:00  183.419998  184.850006  181.669998  182.309998
# 2024-02-20 00:00:00-05:00  181.789993  182.429993  180.000000  181.559998
# 2024-02-21 00:00:00-05:00  181.940002  182.889999  180.660004  182.320007
# 2024-02-22 00:00:00-05:00  183.479996  184.960007  182.460007  184.369995
# 2024-02-23 00:00:00-05:00  185.009995  185.039993  182.229996  182.520004
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-02-25 00:00:00-05:00   87493600        0.0           0.0
# 2019-02-26 00:00:00-05:00   68280800        0.0           0.0
# 2019-02-27 00:00:00-05:00  111341600        0.0           0.0
# 2019-02-28 00:00:00-05:00  112861600        0.0           0.0
# 2019-03-01 00:00:00-05:00  103544800        0.0           0.0
# ...                              ...        ...           ...
# 2024-02-16 00:00:00-05:00   49701400        0.0           0.0
# 2024-02-20 00:00:00-05:00   53665600        0.0           0.0
# 2024-02-21 00:00:00-05:00   41529700        0.0           0.0
# 2024-02-22 00:00:00-05:00   52292200        0.0           0.0
# 2024-02-23 00:00:00-05:00   45074500        0.0           0.0
#
# [1259 rows x 7 columns]

# %%
ticker = "NVDA"
nvda = yf.Ticker(ticker).history(period="5y")
nvda
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-02-25 00:00:00-05:00   40.324321   40.999040   39.277516   39.364338
# 2019-02-26 00:00:00-05:00   39.317212   39.877822   38.635053   38.969933
# 2019-02-27 00:00:00-05:00   38.826050   39.091470   37.980171   38.550705
# 2019-02-28 00:00:00-05:00   38.488632   38.712113   38.081397   38.304878
# 2019-03-01 00:00:00-05:00   38.803995   39.270823   38.220456   38.848690
# ...                               ...         ...         ...         ...
# 2024-02-16 00:00:00-05:00  741.000000  744.020020  725.010010  726.130005
# 2024-02-20 00:00:00-05:00  719.469971  719.559998  677.340027  694.520020
# 2024-02-21 00:00:00-05:00  680.059998  688.880005  662.479980  674.719971
# 2024-02-22 00:00:00-05:00  750.250000  785.750000  742.200012  785.380005
# 2024-02-23 00:00:00-05:00  807.900024  823.940002  775.700012  788.169983
#
#                              Volume  Dividends  Stock Splits
# Date
# 2019-02-25 00:00:00-05:00  65602000       0.00           0.0
# 2019-02-26 00:00:00-05:00  48846400       0.00           0.0
# 2019-02-27 00:00:00-05:00  50025600       0.00           0.0
# 2019-02-28 00:00:00-05:00  32494400       0.04           0.0
# 2019-03-01 00:00:00-05:00  35718800       0.00           0.0
# ...                             ...        ...           ...
# 2024-02-16 00:00:00-05:00  49391800       0.00           0.0
# 2024-02-20 00:00:00-05:00  70483300       0.00           0.0
# 2024-02-21 00:00:00-05:00  69029800       0.00           0.0
# 2024-02-22 00:00:00-05:00  86510000       0.00           0.0
# 2024-02-23 00:00:00-05:00  82711200       0.00           0.0
#
# [1259 rows x 7 columns]

# %% [markdown]
# ## Creating the Chart

# %%
# Multiple plots without rebase

title = "AAPL vs NVDA"
style = "tableau"
max_bars = 250

indicators = [
    Candlesticks(),
    Volume(),
    RSI(),
    MACD(),
]

chart = Chart(title=title, max_bars=max_bars, style=style)
chart.plot(aapl, indicators)
chart.plot(nvda, [Price()], target="main")

# %%
# Multiple plots with rebase

chart = Chart(title=title, max_bars=max_bars, style=style)
chart.plot(aapl, indicators)
chart.plot(nvda, [Price()], target="main", rebase=True)
