# %% [markdown]
# # CURVE Indicator Example

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import Candlesticks, Volume

from mplchart.indicators import CURVE, QSF
from mplchart.samples import sample_prices

# %%
prices = sample_prices()

# %%
CURVE(20) @ prices.close
# Out:
# datetime
# 1980-12-12         NaN
# 1980-12-15         NaN
# 1980-12-16         NaN
# 1980-12-17         NaN
# 1980-12-18         NaN
#                 ...
# 2025-11-11   -0.093277
# 2025-11-12   -0.082654
# 2025-11-13   -0.055133
# 2025-11-14   -0.034592
# 2025-11-17   -0.060314
# Name: close, Length: 11325, dtype: float64

# %%
Chart(prices, title="Curve Indicator", max_bars=250).plot(
    Candlesticks(),
    QSF(20),
    Volume(),
).plot(
    CURVE(20), target="below"
).show()
