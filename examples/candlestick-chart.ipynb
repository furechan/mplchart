# %% [markdown]
# # Candlestick Chart

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import Candlesticks

# %%
# intervals: 1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo

ticker, interval, period = "AAPL", "1m", "7d"

prices = yf.Ticker(ticker).history(interval=interval, period="period")
prices.tail(5)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-06-06 12:22:00-04:00  195.725006  195.750000  195.725006  195.744095
# 2024-06-06 12:23:00-04:00  195.740005  195.740005  195.669998  195.720001
# 2024-06-06 12:24:00-04:00  195.714996  195.719803  195.660004  195.675003
# 2024-06-06 12:25:00-04:00  195.675003  195.698700  195.669998  195.695007
# 2024-06-06 12:26:00-04:00  195.684998  195.684998  195.684998  195.684998
#
#                            Volume  Dividends  Stock Splits
# Datetime
# 2024-06-06 12:22:00-04:00   23443        0.0           0.0
# 2024-06-06 12:23:00-04:00   55499        0.0           0.0
# 2024-06-06 12:24:00-04:00   44121        0.0           0.0
# 2024-06-06 12:25:00-04:00   32987        0.0           0.0
# 2024-06-06 12:26:00-04:00       0        0.0           0.0

# %%
max_bars = 250

indicators = [ Candlesticks(use_bars=True) ]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
chart.show()

# %%
max_bars = 250

indicators = [ Candlesticks(colorup="b", colordn="r") ]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
chart.show()

# %%
max_bars = 250

indicators = [ Candlesticks(colorup="b", colordn="r", use_bars=True) ]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
chart.show()
