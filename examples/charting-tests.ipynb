# %% [markdown]
# # Charting Tests

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import *
from mplchart.indicators import *

# %%
ticker = "AAPL"
prices = yf.Ticker(ticker).history(period="5y")
prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-02-28 00:00:00-05:00   41.954421   42.096419   41.617475   41.672829
# 2019-03-01 00:00:00-05:00   41.944785   42.154171   41.610247   42.110851
# 2019-03-04 00:00:00-05:00   42.284142   42.779931   41.870181   42.322651
# 2019-03-05 00:00:00-05:00   42.344317   42.358757   42.007370   42.245640
# 2019-03-06 00:00:00-05:00   42.038652   42.236007   41.862960   42.002552
# ...                               ...         ...         ...         ...
# 2024-02-22 00:00:00-05:00  183.479996  184.960007  182.460007  184.369995
# 2024-02-23 00:00:00-05:00  185.009995  185.039993  182.229996  182.520004
# 2024-02-26 00:00:00-05:00  182.240005  182.759995  180.649994  181.160004
# 2024-02-27 00:00:00-05:00  181.100006  183.919998  179.559998  182.630005
# 2024-02-28 00:00:00-05:00  182.509995  183.119995  180.960007  181.190002
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-02-28 00:00:00-05:00  112861600        0.0           0.0
# 2019-03-01 00:00:00-05:00  103544800        0.0           0.0
# 2019-03-04 00:00:00-05:00  109744800        0.0           0.0
# 2019-03-05 00:00:00-05:00   78949600        0.0           0.0
# 2019-03-06 00:00:00-05:00   83241600        0.0           0.0
# ...                              ...        ...           ...
# 2024-02-22 00:00:00-05:00   52292200        0.0           0.0
# 2024-02-23 00:00:00-05:00   45074500        0.0           0.0
# 2024-02-26 00:00:00-05:00   40867400        0.0           0.0
# 2024-02-27 00:00:00-05:00   54219400        0.0           0.0
# 2024-02-28 00:00:00-05:00   17723124        0.0           0.0
#
# [1259 rows x 7 columns]

# %%
style = "tableau"
max_bars = 250

indicators = [
    Candlesticks(),
    SMA(50),
    SMA(200),
    Volume(),
    RSI(),
    ADX(),
    MACD(),
]

chart = Chart(title=ticker, max_bars=max_bars, style=style)
chart.plot(prices, indicators)
