# %% [markdown]
# # Charting Tests

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import *
from mplchart.indicators import *

# %%
ticker = "AAPL"
prices = yf.Ticker(ticker).history(period="5y")
prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-03-12 00:00:00-04:00   43.321448   43.964049   43.169821   43.540462
# 2019-03-13 00:00:00-04:00   43.862957   44.115666   43.542859   43.732994
# 2019-03-14 00:00:00-04:00   44.260080   44.308218   43.937577   44.219166
# 2019-03-15 00:00:00-04:00   44.488722   45.085594   44.221573   44.794376
# 2019-03-18 00:00:00-04:00   44.717365   45.340712   44.714956   45.251663
# ...                               ...         ...         ...         ...
# 2024-03-06 00:00:00-05:00  171.059998  171.240005  168.679993  169.119995
# 2024-03-07 00:00:00-05:00  169.149994  170.729996  168.490005  169.000000
# 2024-03-08 00:00:00-05:00  169.000000  173.699997  168.940002  170.729996
# 2024-03-11 00:00:00-04:00  172.940002  174.380005  172.050003  172.750000
# 2024-03-12 00:00:00-04:00  173.149994  173.470001  171.020004  173.169998
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-03-12 00:00:00-04:00  129870400        0.0           0.0
# 2019-03-13 00:00:00-04:00  124130000        0.0           0.0
# 2019-03-14 00:00:00-04:00   94318000        0.0           0.0
# 2019-03-15 00:00:00-04:00  156171600        0.0           0.0
# 2019-03-18 00:00:00-04:00  104879200        0.0           0.0
# ...                              ...        ...           ...
# 2024-03-06 00:00:00-05:00   68587700        0.0           0.0
# 2024-03-07 00:00:00-05:00   71765100        0.0           0.0
# 2024-03-08 00:00:00-05:00   76114600        0.0           0.0
# 2024-03-11 00:00:00-04:00   60068800        0.0           0.0
# 2024-03-12 00:00:00-04:00   33528290        0.0           0.0
#
# [1260 rows x 7 columns]

# %%
style = "tableau"
max_bars = 100

indicators = [
    Candlesticks(),
    SMA(50),
    SMA(200),
    Volume(),
    RSI(),
    ADX(),
    MACD(),
]

chart = Chart(title=ticker, max_bars=max_bars, style=style)
chart.plot(prices, indicators)
chart.show()
