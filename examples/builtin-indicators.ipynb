# %% [markdown]
# # A quick tour of builtin indicators

# %%
import yfinance as yf

from mplchart.chart import Chart

from mplchart.primitives import Candlesticks, Volume, SameAxes
from mplchart.indicators import ROC, SMA, EMA, ADX, RSI, MACD, SLOPE, BBANDS

# %%
ticker = "AAPL"
prices = yf.Ticker(ticker).history(period="5y")
prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-03-18 00:00:00-04:00   44.717357   45.340704   44.714948   45.251656
# 2019-03-19 00:00:00-04:00   45.331085   45.485116   44.746243   44.893055
# 2019-03-20 00:00:00-04:00   44.820862   45.605464   44.459850   45.285366
# 2019-03-21 00:00:00-04:00   45.733009   47.251666   45.682466   46.953228
# 2019-03-22 00:00:00-04:00   47.013400   47.578987   45.915924   45.980907
# ...                               ...         ...         ...         ...
# 2024-03-11 00:00:00-04:00  172.940002  174.380005  172.050003  172.750000
# 2024-03-12 00:00:00-04:00  173.149994  174.029999  171.009995  173.229996
# 2024-03-13 00:00:00-04:00  172.770004  173.190002  170.759995  171.130005
# 2024-03-14 00:00:00-04:00  172.910004  174.309998  172.050003  173.000000
# 2024-03-15 00:00:00-04:00  171.000000  172.619995  170.289993  172.619995
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
max_bars = 250

indicators = [
    Candlesticks(),
    SMA(50),
    SMA(200),
    Volume(),
    RSI(),
    MACD(),
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %%
max_bars = 250
indicators = [Candlesticks(), EMA(20), EMA(50), SLOPE(20), SameAxes(), SLOPE(50)]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %%
max_bars = 250
indicators = [Candlesticks(), BBANDS()]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %%
max_bars = 250
indicators = [Candlesticks(), ADX()]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %%
max_bars = 250
indicators = [Candlesticks(), ROC()]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
