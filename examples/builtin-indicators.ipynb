# %% [markdown]
# # Builtin indicators

# %%
import yfinance as yf

from mplchart.chart import Chart

from mplchart.primitives import Candlesticks, Volume, SameAxes
from mplchart.indicators import ROC, SMA, EMA, ADX, RSI, MACD, SLOPE, BBANDS

# %%
ticker = "AAPL"
prices = yf.Ticker(ticker).history(period="5y")
prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-06-10 00:00:00-04:00   46.278833   47.137769   46.232990   46.464615
# 2019-06-11 00:00:00-04:00   47.014716   47.289768   46.710711   47.002651
# 2019-06-12 00:00:00-04:00   46.795151   47.282526   46.660038   46.853058
# 2019-06-13 00:00:00-04:00   46.976104   47.480367   46.710705   46.843403
# 2019-06-14 00:00:00-04:00   46.216095   46.708293   45.914502   46.503212
# ...                               ...         ...         ...         ...
# 2024-06-03 00:00:00-04:00  192.899994  194.990005  192.520004  194.029999
# 2024-06-04 00:00:00-04:00  194.639999  195.320007  193.029999  194.350006
# 2024-06-05 00:00:00-04:00  195.399994  196.899994  194.869995  195.869995
# 2024-06-06 00:00:00-04:00  195.690002  196.500000  194.169998  194.479996
# 2024-06-07 00:00:00-04:00  194.649994  196.940002  194.139999  196.889999
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-06-10 00:00:00-04:00  104883600        0.0           0.0
# 2019-06-11 00:00:00-04:00  107731600        0.0           0.0
# 2019-06-12 00:00:00-04:00   73012800        0.0           0.0
# 2019-06-13 00:00:00-04:00   86698400        0.0           0.0
# 2019-06-14 00:00:00-04:00   75046000        0.0           0.0
# ...                              ...        ...           ...
# 2024-06-03 00:00:00-04:00   50080500        0.0           0.0
# 2024-06-04 00:00:00-04:00   47471400        0.0           0.0
# 2024-06-05 00:00:00-04:00   54156800        0.0           0.0
# 2024-06-06 00:00:00-04:00   41181800        0.0           0.0
# 2024-06-07 00:00:00-04:00   53044700        0.0           0.0
#
# [1259 rows x 7 columns]

# %%
max_bars = 250

indicators = [
    Candlesticks(),
    SMA(50),
    SMA(200),
    Volume(),
    RSI(),
    MACD(),
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %%
max_bars = 250
indicators = [Candlesticks(), EMA(20), EMA(50), SLOPE(20), SameAxes(), SLOPE(50)]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %%
max_bars = 250
indicators = [Candlesticks(), BBANDS()]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %%
max_bars = 250
indicators = [Candlesticks(), ADX()]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %%
max_bars = 250
indicators = [Candlesticks(), ROC()]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
