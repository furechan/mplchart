# %% [markdown]
# # A quick tour of builtin indicators

# %%
import yfinance as yf

from mplchart.chart import Chart

from mplchart.primitives import Candlesticks, Volume, SameAxes
from mplchart.indicators import ROC, SMA, EMA, RSI, MACD, SLOPE, BBANDS

# %%
ticker = "AAPL"
prices = yf.download(ticker, period="5y", progress=False, auto_adjust=True)
prices
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2018-12-31   38.039704   38.238866   37.547801   37.850143  140014000
# 2019-01-02   37.166273   38.116488   37.007904   37.893330  148158800
# 2019-01-03   34.548391   34.965910   34.073286   34.118877  365248800
# 2019-01-04   34.680363   35.644974   34.505199   35.575386  234428400
# 2019-01-07   35.680969   35.712164   35.009101   35.496204  219111200
# ...                ...         ...         ...         ...        ...
# 2023-12-22  195.179993  195.410004  192.970001  193.600006   37122800
# 2023-12-26  193.610001  193.889999  192.830002  193.050003   28919300
# 2023-12-27  192.490005  193.500000  191.089996  193.149994   48087700
# 2023-12-28  194.139999  194.660004  193.169998  193.580002   34049900
# 2023-12-29  193.899994  194.399994  191.729996  192.529999   42628800
#
# [1259 rows x 5 columns]

# %%
max_bars = 250

indicators = [
    Candlesticks(),
    SMA(50),
    SMA(200),
    Volume(),
    RSI(),
    MACD(),
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %%
max_bars = 250
indicators = [Candlesticks(), SLOPE(20), SameAxes(), SLOPE(50)]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %%
max_bars = 250
indicators = [Candlesticks(), BBANDS()]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
