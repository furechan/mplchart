# %% [markdown]
# # mplchart typical usage

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import OHLC, Candlesticks, Volume
from mplchart.indicators import SMA, RSI, MACD

# %% [markdown]
# ## Fetching the prices

# %%
ticker = 'AAPL'
prices = yf.Ticker(ticker).history(period='5y')
prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2018-11-14 00:00:00-05:00   46.526824   46.665997   44.614401   44.823162
# 2018-11-15 00:00:00-05:00   45.204694   46.063725   44.847163   45.929352
# 2018-11-16 00:00:00-05:00   45.711000   46.783590   45.461451   46.438057
# 2018-11-19 00:00:00-05:00   45.591022   45.758989   44.388860   44.597618
# 2018-11-20 00:00:00-05:00   42.800373   43.544228   42.114108   42.466839
# ...                               ...         ...         ...         ...
# 2023-11-07 00:00:00-05:00  178.944239  182.199959  178.734524  181.580780
# 2023-11-08 00:00:00-05:00  182.110085  183.208629  181.351076  182.649368
# 2023-11-09 00:00:00-05:00  182.719278  183.877740  181.570782  182.169998
# 2023-11-10 00:00:00-05:00  183.970001  186.570007  183.529999  186.399994
# 2023-11-13 00:00:00-05:00  185.820007  186.029999  184.210007  184.800003
#
#                               Volume  Dividends  Stock Splits
# Date
# 2018-11-14 00:00:00-05:00  243204000       0.00           0.0
# 2018-11-15 00:00:00-05:00  185915200       0.00           0.0
# 2018-11-16 00:00:00-05:00  147713200       0.00           0.0
# 2018-11-19 00:00:00-05:00  167701200       0.00           0.0
# 2018-11-20 00:00:00-05:00  271300800       0.00           0.0
# ...                              ...        ...           ...
# 2023-11-07 00:00:00-05:00   70530000       0.00           0.0
# 2023-11-08 00:00:00-05:00   49340300       0.00           0.0
# 2023-11-09 00:00:00-05:00   53763500       0.00           0.0
# 2023-11-10 00:00:00-05:00   66133400       0.24           0.0
# 2023-11-13 00:00:00-05:00   40509693       0.00           0.0
#
# [1257 rows x 7 columns]

# %% [markdown]
# ## Creating the Chart

# %%
style = 'tableau'
max_bars = 250

indicators = [
    Candlesticks(), SMA(50), SMA(200), Volume(),
    RSI(),
    MACD(),
]

chart = Chart(title=ticker, max_bars=max_bars, style=style)
chart.plot(prices, indicators)
