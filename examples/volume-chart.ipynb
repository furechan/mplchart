# %% [markdown]
# # Volume Chart

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import Volume

# %%
# intervals: 1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo

ticker, interval, period = "AAPL", "1m", "5d"

prices = yf.Ticker(ticker).history(interval=interval, period=period)
prices.tail(5)
# Out:
#                                  Open        High         Low       Close  \
# Datetime
# 2024-06-07 15:55:00-04:00  196.669998  196.830002  196.589996  196.740005
# 2024-06-07 15:56:00-04:00  196.740005  196.779999  196.691299  196.720001
# 2024-06-07 15:57:00-04:00  196.729996  196.880005  196.720001  196.869995
# 2024-06-07 15:58:00-04:00  196.869995  196.899994  196.809998  196.850006
# 2024-06-07 15:59:00-04:00  196.849899  196.940002  196.710007  196.899994
#
#                            Volume  Dividends  Stock Splits
# Datetime
# 2024-06-07 15:55:00-04:00  552803        0.0           0.0
# 2024-06-07 15:56:00-04:00  339459        0.0           0.0
# 2024-06-07 15:57:00-04:00  392364        0.0           0.0
# 2024-06-07 15:58:00-04:00  521864        0.0           0.0
# 2024-06-07 15:59:00-04:00  913249        0.0           0.0

# %%
max_bars = 50

indicators = [ Volume(50) ]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
chart.show()
