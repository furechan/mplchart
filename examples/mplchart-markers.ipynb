# %% [markdown]
# # Trade markers

# %%
import yfinance as yf

from mplchart.chart import Chart

from mplchart.primitives import Candlesticks, Volume, TradeMarker, TradeSpan

from mplchart.indicators import SMA, EMA, RSI, MACD, PPO

# %%
max_bars = 250
ticker = 'AAPL'
prices = yf.Ticker(ticker).history('5y')
prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2018-10-25 00:00:00-04:00   52.127057   53.005777   51.897199   52.627472
# 2018-10-26 00:00:00-04:00   51.693672   52.720844   50.920303   51.789448
# 2018-10-29 00:00:00-04:00   52.481418   52.601135   49.344838   50.817356
# 2018-10-30 00:00:00-04:00   50.556360   51.521276   50.106228   51.071144
# 2018-10-31 00:00:00-04:00   51.928316   52.783092   51.866061   52.402393
# ...                               ...         ...         ...         ...
# 2023-10-19 00:00:00-04:00  176.039993  177.839996  175.190002  175.460007
# 2023-10-20 00:00:00-04:00  175.309998  175.419998  172.639999  172.880005
# 2023-10-23 00:00:00-04:00  170.910004  174.009995  169.929993  173.000000
# 2023-10-24 00:00:00-04:00  173.050003  173.669998  171.449997  173.440002
# 2023-10-25 00:00:00-04:00  171.880005  173.059998  170.809998  170.905106
#
#                               Volume  Dividends  Stock Splits
# Date
# 2018-10-25 00:00:00-04:00  119423200        0.0           0.0
# 2018-10-26 00:00:00-04:00  189033600        0.0           0.0
# 2018-10-29 00:00:00-04:00  183742000        0.0           0.0
# 2018-10-30 00:00:00-04:00  146640000        0.0           0.0
# 2018-10-31 00:00:00-04:00  153435600        0.0           0.0
# ...                              ...        ...           ...
# 2023-10-19 00:00:00-04:00   59302900        0.0           0.0
# 2023-10-20 00:00:00-04:00   64189300        0.0           0.0
# 2023-10-23 00:00:00-04:00   55980100        0.0           0.0
# 2023-10-24 00:00:00-04:00   43764100        0.0           0.0
# 2023-10-25 00:00:00-04:00   29502047        0.0           0.0
#
# [1258 rows x 7 columns]

# %% [markdown]
# TradeMarker will show the performance of a position as calculated as an expression over to the previous indicator.
# This currently works only for a few indicatores like MACD, PPO, ...

# %%
indicators = [
    Candlesticks(), SMA(50), SMA(200), Volume(),
    RSI(), MACD(), TradeMarker('macdhist>0')
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %% [markdown]
# TradeSpan will show the span of a position as calculated by an expression over to the previous indicator.
# This currently works for a few indicatores like MACD, PPO, ...

# %%
indicators = [
    Candlesticks(), SMA(50), SMA(200), Volume(),
    RSI(), MACD(), TradeSpan('macdhist>0')
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
