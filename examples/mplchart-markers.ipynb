# %% [markdown]
# # mplchart trade markers

# %%
import yfinance as yf

from mplchart.chart import Chart

from mplchart.primitives import Candlesticks, Volume, TradeMarker, TradeSpan

from mplchart.indicators import SMA, EMA, RSI, MACD, PPO

# %%
max_bars = 250
ticker = 'AAPL'
prices = yf.Ticker(ticker).history('5y')
prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2018-09-04 00:00:00-04:00   54.688986   54.873347   54.262795   54.677013
# 2018-09-05 00:00:00-04:00   54.827857   54.990670   53.896461   54.320255
# 2018-09-06 00:00:00-04:00   54.167023   54.435191   52.986618   53.417599
# 2018-09-07 00:00:00-04:00   53.118296   53.961099   52.845342   52.986607
# 2018-09-10 00:00:00-04:00   52.902816   53.118308   51.830155   52.275501
# ...                               ...         ...         ...         ...
# 2023-08-28 00:00:00-04:00  180.089996  180.589996  178.550003  180.190002
# 2023-08-29 00:00:00-04:00  179.699997  184.899994  179.500000  184.119995
# 2023-08-30 00:00:00-04:00  184.940002  187.850006  184.740005  187.649994
# 2023-08-31 00:00:00-04:00  187.839996  189.119995  187.479996  187.869995
# 2023-09-01 00:00:00-04:00  189.490005  189.919998  188.279999  189.460007
#
#                               Volume  Dividends  Stock Splits
# Date
# 2018-09-04 00:00:00-04:00  109560400        0.0           0.0
# 2018-09-05 00:00:00-04:00  133332000        0.0           0.0
# 2018-09-06 00:00:00-04:00  137160000        0.0           0.0
# 2018-09-07 00:00:00-04:00  150479200        0.0           0.0
# 2018-09-10 00:00:00-04:00  158066000        0.0           0.0
# ...                              ...        ...           ...
# 2023-08-28 00:00:00-04:00   43820700        0.0           0.0
# 2023-08-29 00:00:00-04:00   53003900        0.0           0.0
# 2023-08-30 00:00:00-04:00   60813900        0.0           0.0
# 2023-08-31 00:00:00-04:00   60794500        0.0           0.0
# 2023-09-01 00:00:00-04:00   45732600        0.0           0.0
#
# [1258 rows x 7 columns]

# %% [markdown]
# TradeMarker will show the performance of a position as calculated as an expression over to the previous indicator.
# This currently works only for a few indicatores like MACD, PPO, ...

# %%
indicators = [
    Candlesticks(), SMA(50), SMA(200), Volume(),
    RSI(), MACD(), TradeMarker('macdhist>0')
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %% [markdown]
# TradeSpan will show the span of a position as calculated by an expression over to the previous indicator.
# This currently works for a few indicatores like MACD, PPO, ...

# %%
indicators = [
    Candlesticks(), SMA(50), SMA(200), Volume(),
    RSI(), MACD(), TradeSpan('macdhist>0')
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
