# %% [markdown]
# # mplchart trade markers (experimental)

# %%
from mplchart.chart import Chart
from mplchart.helper import get_prices

from mplchart.primitives import Candlesticks, Volume, TradeMarker, TradeSpan

from mplchart.indicators import SMA, EMA, RSI, MACD, PPO

from matplotlib_inline.backend_inline import set_matplotlib_formats

set_matplotlib_formats('svg')

# %%
max_bars = 250
ticker = 'AAPL'
freq = 'daily'
prices = get_prices(ticker, freq=freq)
prices.tail()
# Out:
#                   open        high         low       close    volume
# date
# 2022-08-02  159.877927  162.184720  159.408578  159.788040  59907000
# 2022-08-03  160.616896  166.358920  160.527024  165.899567  82507500
# 2022-08-04  165.779721  166.958093  164.201911  165.580002  55474100
# 2022-08-05  163.210007  165.850006  163.000000  165.350006  56646600
# 2022-08-08  166.369995  167.809998  164.199997  164.869995  60276900

# %% [markdown]
# TradeMarker will show the performance of a position as calculated as an expression over to the previous indicator.
# This currently works only for a few indicatores like MACD, PPO, ...

# %%
indicators = [
    Candlesticks(), SMA(50), SMA(200), Volume(),
    RSI(), MACD(), TradeMarker('macdhist>0')
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %% [markdown]
# TradeSpan will show the span of a position as calculated by an expression over to the previous indicator.
# This currently works for a few indicatores like MACD, PPO, ...

# %%
indicators = [
    Candlesticks(), SMA(50), SMA(200), Volume(),
    RSI(), MACD(), TradeSpan('macdhist>0')
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %% [markdown]
# TradeMarker and TrasdeSpan can of course be combined

# %%
indicators = [
    Candlesticks(), SMA(50), SMA(200), Volume(),
    RSI(), MACD(), TradeMarker('macdhist>0'), TradeSpan('macdhist>0')
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
