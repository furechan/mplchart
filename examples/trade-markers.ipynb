# %% [markdown]
# # Trade markers

# %%
import yfinance as yf

from mplchart.chart import Chart

from mplchart.primitives import Candlesticks, Volume, TradeMarker, TradeSpan

from mplchart.indicators import SMA, EMA, RSI, MACD, PPO

# %%
max_bars = 250
ticker = "AAPL"
prices = yf.download(ticker, period="5y", auto_adjust=True)
prices
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2018-12-17 00:00:00-05:00   39.700180   40.396045   39.047508   39.337852
# 2018-12-18 00:00:00-05:00   39.683374   40.199271   39.445819   39.848942
# 2018-12-19 00:00:00-05:00   39.832142   40.180073   38.174068   38.605984
# 2018-12-20 00:00:00-05:00   38.488408   38.898729   37.264651   37.631779
# 2018-12-21 00:00:00-05:00   37.638991   37.950930   35.904134   36.168079
# ...                               ...         ...         ...         ...
# 2023-12-11 00:00:00-05:00  193.110001  193.490005  191.419998  193.179993
# 2023-12-12 00:00:00-05:00  193.080002  194.720001  191.720001  194.710007
# 2023-12-13 00:00:00-05:00  195.089996  198.000000  194.850006  197.960007
# 2023-12-14 00:00:00-05:00  198.020004  199.619995  196.160004  198.110001
# 2023-12-15 00:00:00-05:00  197.529999  198.399902  197.020004  197.570007
#
#                               Volume  Dividends  Stock Splits
# Date
# 2018-12-17 00:00:00-05:00  177151600        0.0           0.0
# 2018-12-18 00:00:00-05:00  135366000        0.0           0.0
# 2018-12-19 00:00:00-05:00  196189200        0.0           0.0
# 2018-12-20 00:00:00-05:00  259092000        0.0           0.0
# 2018-12-21 00:00:00-05:00  382978400        0.0           0.0
# ...                              ...        ...           ...
# 2023-12-11 00:00:00-05:00   60943700        0.0           0.0
# 2023-12-12 00:00:00-05:00   52696900        0.0           0.0
# 2023-12-13 00:00:00-05:00   70404200        0.0           0.0
# 2023-12-14 00:00:00-05:00   66831600        0.0           0.0
# 2023-12-15 00:00:00-05:00  114815314        0.0           0.0
#
# [1259 rows x 7 columns]

# %% [markdown]
# TradeMarker will show the performance of a position as calculated as an expression over to the previous indicator.
# This currently works only for a few indicatores like MACD, PPO, ...

# %%
indicators = [
    Candlesticks(),
    SMA(50),
    SMA(200),
    Volume(),
    RSI(),
    MACD(),
    TradeMarker("macdhist>0"),
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)

# %% [markdown]
# TradeSpan will show the span of a position as calculated by an expression over to the previous indicator.
# This currently works for a few indicatores like MACD, PPO, ...

# %%
indicators = [
    Candlesticks(),
    SMA(50),
    SMA(200),
    Volume(),
    RSI(),
    MACD(),
    TradeSpan("macdhist>0"),
]

chart = Chart(title=ticker, max_bars=max_bars)
chart.plot(prices, indicators)
