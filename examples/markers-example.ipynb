# %% [markdown]
# # Markers Primitive Example

# %%
import yfinance as yf

from mplchart.chart import Chart
from mplchart.primitives import Candlesticks, Volume, Markers

from mplchart.indicators import SMA, RSI, MACD

# %%
ticker = "AAPL"
prices = yf.Ticker(ticker).history(period="5y")
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1256 entries, 2021-03-01 00:00:00-05:00 to 2026-02-27 00:00:00-05:00
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Open          1256 non-null   float64
#  1   High          1256 non-null   float64
#  2   Low           1256 non-null   float64
#  3   Close         1256 non-null   float64
#  4   Volume        1256 non-null   int64
#  5   Dividends     1256 non-null   float64
#  6   Stock Splits  1256 non-null   float64
# dtypes: float64(6), int64(1)
# memory usage: 78.5 KB

# %%
# Markers can be used to mark changes in an indicator above/below zero
# By default the primitive is applied to the last indicator that was plotted


Chart(prices, title=ticker, max_bars=250).plot(
    Candlesticks(),
    SMA(50),
    SMA(200),
    Volume(),
).plot(
    RSI(),
    target="above"
).plot(
    MACD(),
    Markers("macdhist", color=["red", "green"], alpha=1.0),
    target="below"
).show()
