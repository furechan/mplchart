# %%
import yfinance as yf
from mplchart.chart import Chart
from mplchart.primitives import Candlesticks, Volume, ReversalPatternProperties, Reversal

ticker = "AAPL"
prices = yf.Ticker(ticker).history(period="1y")

# %%
# Configure pattern scanning
scan_props = ReversalPatternProperties(
    peak_diff_threshold=0.03,
)


indicators = [
    Candlesticks(colorup="green", colordn="red"),
    Volume(),
    Reversal(backcandels=2, forwardcandels=2, pivot_limit=100, show_pivots=True, scan_props=scan_props),
    # SMA(50),
    # SMA(200),
    # RSI(),
    # MACD(),
]

chart = Chart(title=ticker, figsize=(20, 8))
chart.plot(prices, indicators)
# Out:
# pivots 3 249, 0.023, 0.03
# inspect_five_pivot_pattern 239, 248, 251
# pivots 3 248, -0.065, 0.03
# pivots 3 244, -0.089, 0.03
# pivots 3 239, -0.031, 0.03
# pivots 3 236, 0.071, 0.03
# pivots 3 230, 0.179, 0.03
# pivots 3 224, -0.019, 0.03
# inspect_five_pivot_pattern 219, 223, 230
# pivots 3 223, -0.055, 0.03
# pivots 3 221, -0.011, 0.03
# inspect_five_pivot_pattern 213, 219, 223
# pivots 3 219, -0.001, 0.03
# inspect_five_pivot_pattern 209, 216, 221
# pivots 3 216, 0.112, 0.03
# pivots 3 213, 0.1, 0.03
# pivots 3 209, -0.031, 0.03
# pivots 3 208, -0.098, 0.03
# pivots 3 204, -0.18, 0.03
# pivots 3 198, 0.051, 0.03
# pivots 3 195, 0.312, 0.03
# pivots 3 193, 0.033, 0.03
# pivots 3 180, -0.206, 0.03
# pivots 3 179, -0.129, 0.03
# pivots 3 173, -0.25, 0.03
# pivots 3 165, 0.046, 0.03
# pivots 3 163, 0.212, 0.03
# pivots 3 162, 0.143, 0.03
# pivots 3 151, 0.16, 0.03
# pivots 3 144, 0.301, 0.03
# pivots 3 142, 0.061, 0.03
# pivots 3 133, 0.002, 0.03
# pivots 3 131, -0.026, 0.03
# inspect_five_pivot_pattern 117, 130, 133
# pivots 3 130, 0.067, 0.03
# pivots 3 128, 0.223, 0.03
# pivots 3 117, 0.121, 0.03
# pivots 3 115, 0.056, 0.03
# pivots 3 113, -0.026, 0.03
# pivots 3 107, -0.034, 0.03
# pivots 3 102, 0.071, 0.03
# pivots 3 100, -0.012, 0.03
# inspect_five_pivot_pattern 91, 96, 102
# pivots 3 96, -0.019, 0.03
# inspect_five_pivot_pattern 89, 94, 100
# pivots 3 94, -0.013, 0.03
# inspect_five_pivot_pattern 86, 91, 96
# pivots 3 91, -0.056, 0.03
# pivots 3 89, -0.009, 0.03
# pivots 3 86, 0.047, 0.03
# pivots 3 83, 0.02, 0.03
# inspect_five_pivot_pattern 68, 79, 86
# pivots 3 79, -0.118, 0.03
# pivots 3 77, -0.127, 0.03
# pivots 3 68, -0.064, 0.03
# pivots 3 65, 0.011, 0.03
# inspect_five_pivot_pattern 47, 57, 68
# pivots 3 57, -0.059, 0.03
# pivots 3 54, -0.012, 0.03
# pivots 3 47, 0.103, 0.03
# pivots 3 42, 0.001, 0.03
# inspect_five_pivot_pattern 30, 39, 47
# pivots 3 39, -0.084, 0.03
# pivots 3 35, -0.121, 0.03
# pivots 3 30, -0.033, 0.03
# pivots 3 29, -0.036, 0.03
# pivots 3 25, -0.021, 0.03
# inspect_five_pivot_pattern 18, 23, 29
# pivots 3 23, 0.033, 0.03
# pivots 3 21, 0.04, 0.03
# pivots 3 18, 0.044, 0.03
# pivots 3 17, 0.043, 0.03
# pivots 3 13, -0.016, 0.03
# inspect_five_pivot_pattern 6, 10, 17
# pivots 3 10, -0.009, 0.03
# inspect_five_pivot_pattern 0, 8, 13
