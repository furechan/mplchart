# %%
from mplchart.chart import Chart
from mplchart.helper import get_prices

from mplchart.primitives import Candlesticks, OHLC, Price, Volume

# %% [markdown]
# ## Fetching the prices

# %%
ticker = 'NVDA'
freq = 'daily'
prices = get_prices(ticker, freq=freq)
prices
# Out:
#                   open        high         low       close       volume
# date
# 1999-01-22    0.401739    0.448369    0.356304    0.376630  271468800.0
# 1999-01-25    0.406521    0.420869    0.376630    0.416086   51048000.0
# 1999-01-26    0.420869    0.429239    0.377825    0.383804   34320000.0
# 1999-01-27    0.385000    0.394565    0.363477    0.382609   24436800.0
# 1999-01-28    0.382609    0.385000    0.379021    0.381413   22752000.0
# ...                ...         ...         ...         ...          ...
# 2022-08-01  181.820007  188.460007  179.899994  184.410004   47646900.0
# 2022-08-02  181.220001  189.380005  180.919998  185.259995   48952700.0
# 2022-08-03  181.839996  189.679993  181.369995  188.929993   41814600.0
# 2022-08-04  188.490005  192.740005  187.600006  192.149994   40965200.0
# 2022-08-05  188.100006  192.289993  186.660004  189.889999   38580100.0
#
# [5925 rows x 5 columns]

# %% [markdown]
# ## Candlestics plot with Candlesticks()

# %%
max_bars = 250
indicators = [ Candlesticks() ]

chart = Chart(title=ticker, max_bars=max_bars, figsize=(12, 9))
chart.plot(prices, indicators)

# %% [markdown]
# ## Open High Low close bars with OHLC()

# %%
max_bars = 250
indicators = [ OHLC() ]

chart = Chart(title=ticker, max_bars=max_bars, figsize=(12, 9))
chart.plot(prices, indicators)

# %% [markdown]
# ## Simple price plot with Price()

# %%
max_bars = 250
indicators = [ Price() ]

chart = Chart(title=ticker, max_bars=max_bars, figsize=(12, 9))
chart.plot(prices, indicators)

# %% [markdown]
# ## Volume plot with Volume()

# %%
max_bars = 250
indicators = [ Volume() ]

chart = Chart(title=ticker, max_bars=max_bars, figsize=(12, 9))
chart.plot(prices, indicators)

# %% [markdown]
# ## Price and Volume combined

# %%
max_bars = 250
indicators = [ Price(), Volume() ]

chart = Chart(title=ticker, max_bars=max_bars, figsize=(12, 9))
chart.plot(prices, indicators)
